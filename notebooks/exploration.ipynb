# %%
import pandas as pd

# %%
import os

print(os.getcwd())
# Out:
# /home/mdumar/data_eng/projects/olist-pandas-pipeline/notebooks

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
sys.path.append(str(PROJECT_ROOT))

# %%
from config import BRONZE_PATH

df = pd.read_parquet(BRONZE_PATH / "olist_customers_dataset.parquet")

# %%
df.info()
df.head()

# %%
df = pd.read_parquet("../output/bronze/orders.parquet")

print(df.info())

display(df.head())

display(df.describe(include="all"))

print(df.isna().sum())

print(df.duplicated().sum())

# %% [markdown]
# <!-- ========================================================================= -->
# olist_order_items_dataset.parquet

# %%
df3 = pd.read_parquet("../output/bronze/olist_order_items_dataset.parquet")

# %%
df3.info()

# %%
df3.head()

# %%
display(df3.describe(include="all"))

# %%
print(df3.isna().sum())

# %%
print(df3.duplicated().sum())

# %% [markdown]
# cheacking trensfromtioin is working or not

# %%
df4 = pd.read_parquet("../output/silver/olist_order_items_dataset.parquet")

print(df4.info())

# %% [markdown]
# -----------------------------------------------------------------
# ===============  olist_products_dataset.parquet  check =================

# %%
olist_products = pd.read_parquet("../output/silver/olist_products_dataset.parquet")

# %%
olist_products.info()

# %%
olist_products.head()

# %%
display(olist_products.describe(include="all"))

# %%
print(olist_products.isna().sum())

# %%
print(olist_products.duplicated().sum())

# %%
missing_products = olist_products[olist_products["product_category_name"].isna()]

print(missing_products.head())

print(missing_products.shape)

# %%
text_columns = df.select_dtypes(include="object").columns

for column in text_columns:
    print(f"\nChecking: {column}")
    print(df[column].str.startswith(" ").sum())
    print(df[column].str.endswith(" ").sum())


#  replacing product catogery name with unkonwn

# %%
import pandas as pd

df = pd.read_parquet("output/silver/olist_products_dataset.parquet")

# %%
import os

print(os.getcwd())
import os

print(os.listdir())

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
sys.path.append(str(PROJECT_ROOT))

from config import SILVER_PATH

df = pd.read_parquet(SILVER_PATH / "olist_products_dataset.parquet")


df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  str
#  1   product_category_name       32951 non-null  str
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), str(2)
# memory usage: 3.7 MB

# %%
display(olist_products.describe(include="all"))

# %%
df["product_category_name"].value_counts()["Unknown"]

# %% [markdown]
# sellers dataset.parquet

# %%
sellers = pd.read_parquet(SILVER_PATH / "olist_sellers_dataset.parquet")

# %%
sellers.info()
sellers.head()

# %%
sellers.describe(include="all")

# %%
sellers.isna().sum()

# %%
sellers.duplicated().sum()

# %%
sellers["seller_city"].str.startswith(" ").sum()

# %%
sellers["seller_city"].str.endswith(" ").sum()

# %%
sellers["seller_state"].str.startswith(" ").sum()

# %%
sellers["seller_state"].str.endswith(" ").sum()

# %%
sellers.info()

# %% [markdown]
# product_category_name_translation.parquet

# %%
product_category_name = pd.read_parquet(SILVER_PATH / "product_category_name_translation.parquet")

product_category_name.info()

display(product_category_name.head())

# %%
display(product_category_name.describe(include="all"))

# %%
product_category_name.isna().sum()

product_category_name.duplicated().sum()

# %%
product_category_name["product_category_name"].str.startswith(" ").sum()
product_category_name["product_category_name"].str.endswith(" ").sum()

# %%
product_category_name["product_category_name_english"].str.startswith(" ").sum()
product_category_name["product_category_name_english"].str.endswith(" ").sum()

# %% [markdown]
# olist_order_payments_dataset.parquet

# %%
order_payments = pd.read_parquet(SILVER_PATH /"olist_order_payments_dataset.parquet")

order_payments.info()

display(order_payments.head())

# %%
display(order_payments.describe(include="all"))

# %%
order_payments.isna().sum()

order_payments.duplicated().sum()

# %%
order_payments["payment_type"].str.startswith(" ").sum()
order_payments["payment_type"].str.endswith(" ").sum()

# %%
# order_payments["payment_installments"].min()
order_payments["payment_installments"].max()

# %%
(order_payments["payment_value"] < 0).sum()

(order_payments["payment_installments"] <= 0).sum()

# %%
(order_payments["payment_installments"] <= 0).sum()

# %%
order_payments[order_payments["payment_installments"] <= 0]

# %%
order_payments[
    order_payments["order_id"] == "744bade1fcf9ff3f31d860ace076d422"
]

# %%
order_payments[
    order_payments["order_id"] == "1a57108394169c0b47d8f876acc9ba2d"
]

# %% [markdown]
# Data Quality Note:
# Found 2 records where:
# - payment_type = credit_card
# - payment_installments = 0
#
# These appear inconsistent and should be reviewed  before applying an automatic correction.

# %% [markdown]
# olist_order_reviews_dataset ======================================

# %%
order_reviews = pd.read_parquet(SILVER_PATH /"olist_order_reviews_dataset.parquet")

# %%
order_reviews.info()
order_reviews.head()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  str
#  1   order_id                 99224 non-null  str
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  str
#  4   review_comment_message   40977 non-null  str
#  5   review_creation_date     99224 non-null  datetime64[us]
#  6   review_answer_timestamp  99224 non-null  datetime64[us]
# dtypes: datetime64[us](2), int64(1), str(4)
# memory usage: 14.2 MB
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# ...

# %%
(order_reviews["review_score"] <= 0).sum()
(order_reviews["review_score"] > 5).sum()
# Out:
# np.int64(0)

# %%
# order_reviews.isna().sum()

order_reviews.duplicated().sum()
# Out:
# np.int64(0)

# %%
order_reviews["review_id"].str.startswith(" ").sum()
order_reviews["order_id"].str.endswith(" ").sum()
# Out:
# np.int64(0)

# %%
# Convert dates temporarily for checking
order_reviews["review_creation_date"] = pd.to_datetime(order_reviews["review_creation_date"])

order_reviews["review_answer_timestamp"] = pd.to_datetime(order_reviews["review_answer_timestamp"])

# %%
# Seller answered BEFORE review was created
(
    order_reviews["review_answer_timestamp"]
    < order_reviews["review_creation_date"]
).sum()
# Out:
# np.int64(0)

# %%
order_reviews[
    order_reviews["review_answer_timestamp"]
    < order_reviews["review_creation_date"]
]
# Out:
# Empty DataFrame
# Columns: [review_id, order_id, review_score, review_comment_title, review_comment_message, review_creation_date, review_answer_timestamp]
# Index: []

# %%
print("Review Creation Date")
print(order_reviews["review_creation_date"].min())
print(order_reviews["review_creation_date"].max())

print()

print("Review Answer Date")
print(order_reviews["review_answer_timestamp"].min())
print(order_reviews["review_answer_timestamp"].max())
# Out:
# Review Creation Date
# 2016-10-02 00:00:00
# 2018-08-31 00:00:00
#
# Review Answer Date
# 2016-10-07 18:32:28
# 2018-10-29 12:27:35

# %%
order_reviews[
    ["review_creation_date", "review_answer_timestamp"]
].isna().sum()
# Out:
# review_creation_date       0
# review_answer_timestamp    0
# dtype: int64

# %% [markdown]
# olist_geolocation_dataset  =================================

# %%
olist_geolocation = pd.read_parquet(SILVER_PATH /"olist_geolocation_dataset.parquet")

# %%
olist_geolocation.info()
olist_geolocation.head()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000163 entries, 0 to 1000162
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   geolocation_zip_code_prefix  1000163 non-null  int64
#  1   geolocation_lat              1000163 non-null  float64
#  2   geolocation_lng              1000163 non-null  float64
#  3   geolocation_city             1000163 non-null  str
#  4   geolocation_state            1000163 non-null  str
# dtypes: float64(2), int64(1), str(2)
# memory usage: 50.1 MB
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
# ...

# %%
olist_geolocation.duplicated().sum()
# Out:
# np.int64(261831)

# %%
olist_geolocation.describe(include="all")
# Out:
#         geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# count                  1.000163e+06     1.000163e+06     1.000163e+06
# unique                          NaN              NaN              NaN
# top                             NaN              NaN              NaN
# freq                            NaN              NaN              NaN
# mean                   3.657417e+04    -2.117615e+01    -4.639054e+01
# std                    3.054934e+04     5.715866e+00     4.269748e+00
# min                    1.001000e+03    -3.660537e+01    -1.014668e+02
# 25%                    1.107500e+04    -2.360355e+01    -4.857317e+01
# 50%                    2.653000e+04    -2.291938e+01    -4.663788e+01
# 75%                    6.350400e+04    -1.997962e+01    -4.376771e+01
# max                    9.999000e+04     4.506593e+01     1.211054e+02
#
#        geolocation_city geolocation_state
# count           1000163           1000163
# ...

# %%
olist_geolocation.isna().sum()
# Out:
# geolocation_zip_code_prefix    0
# geolocation_lat                0
# geolocation_lng                0
# geolocation_city               0
# geolocation_state              0
# dtype: int64

# %%
# olist_geolocation["geolocation_city"].str.startswith(" ").sum()
olist_geolocation["geolocation_city"].str.endswith(" ").sum()
# Out:
# np.int64(1)

# %%
olist_geolocation[
    olist_geolocation.duplicated()
].head(20)
# Out:
#      geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 15                          1046       -23.546081       -46.644820
# 44                          1046       -23.546081       -46.644820
# 65                          1046       -23.546081       -46.644820
# 66                          1009       -23.546935       -46.636588
# 67                          1046       -23.546081       -46.644820
# 72                          1046       -23.545320       -46.644069
# 79                          1050       -23.549854       -46.643139
# 80                          1032       -23.540775       -46.635515
# 82                          1046       -23.546081       -46.644820
# 86                          1048       -23.547449       -46.640169
# 89                          1036       -23.541700       -46.641318
# 91                          1013       -23.547325       -46.634184
# 94                          1046       -23.546081       -46.644820
# ...

# %%
olist_geolocation[
    olist_geolocation.duplicated(keep=False)
].head(20)
# Out:
#     geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                          1037       -23.545621       -46.639292
# 1                          1046       -23.546081       -46.644820
# 2                          1046       -23.546129       -46.642951
# 6                          1047       -23.546273       -46.641225
# 7                          1013       -23.546923       -46.634264
# 8                          1029       -23.543769       -46.634278
# 9                          1011       -23.547640       -46.636032
# 10                         1013       -23.547325       -46.634184
# 13                         1012       -23.548946       -46.634671
# 15                         1046       -23.546081       -46.644820
# 16                         1039       -23.541883       -46.639919
# 17                         1024       -23.541390       -46.629899
# 18                         1009       -23.546935       -46.636588
# ...

# %%
geo = pd.read_parquet("../output/silver/olist_geolocation_dataset.parquet")

geo.info()

geo.duplicated().sum()

geo["geolocation_city"].str.endswith(" ").sum()

geo["geolocation_zip_code_prefix"].head()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 738332 entries, 0 to 738331
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   geolocation_zip_code_prefix  738332 non-null  str
#  1   geolocation_lat              738332 non-null  float64
#  2   geolocation_lng              738332 non-null  float64
#  3   geolocation_city             738332 non-null  str
#  4   geolocation_state            738332 non-null  str
# dtypes: float64(2), str(3)
# memory usage: 40.5 MB
# 0    01037
# 1    01046
# 2    01046
# 3    01041
# 4    01035
# Name: geolocation_zip_code_prefix, dtype: str
